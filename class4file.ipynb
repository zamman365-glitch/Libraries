# %% [markdown]
# <a href="https://colab.research.google.com/github/zamman365-glitch/Libraries/blob/main/class4file.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Fancy Indexing
# you can Pick elements from specific positions using a list/array of indices.

# %%
import numpy as np

arr=np.array([10,20,30,40,50,60])

#pick elements at position 0,2,4
arr[[0,2,4]]
# Out:
# array([10, 30, 50])

# %%
import numpy as np
matrix = np.arange(1,13).reshape(3,4)
# matrix[[row0,col1],[row1,col2]]
# matrix[[0,1],[1,2]]
matrix[[1,2],[0,2]]
# Out:
# array([ 5, 11])

# %% [markdown]
# You can do this fancy indexing in 2D Matrix aswell

# %% [markdown]
# ##Conditional Selection
# Find values based on conditions or replace them.

# %%
arr=np.array([5,7,11,18,30])
# we will get the indices only which are greater than 10
np.where(arr>10)

# array mai jaha bhi 10 se choti values aa rahe hai waha 0 se replace ho jayegi
print(np.where(arr>10,arr,0))
# Out:
# [ 0  0 11 18 30]

# %%
arr=np.array([23,25,30,50,100,75,80])
print(np.where(arr>55,arr,0))
# Out:
# [  0   0   0   0 100  75  80]

# %% [markdown]
# ##Sorting & Ordering
# np.sort() → returns sorted array
#
# np.argsort() → returns indices of sorted order

# %%
#Aam Zindagi
array=np.array([2,10,56,1,54])

print(np.sort(array))

index=np.argsort(array)
print(index)
# Out:
# [ 1  2 10 54 56]
# [3 0 1 4 2]

# %% [markdown]
# ##Concatenation & Stacking

# %%
a=np.array([1,2,3])
b=np.array([4,5,6])

np.concatenate([a,b])
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
#Matrix sort
matrix=np.array([[4,3,12],[14,10,15]])
#1. Row wise Sort(axis=1)
np.sort(matrix,axis=1)

#2. Column Wise Sort(axis=0)
np.sort(matrix,axis=0)
# Out:
# array([[ 4,  3, 12],
#        [14, 10, 15]])

# %% [markdown]
# Vertical & Horizontal Stacking

# %%
a=np.array([[1,2],[4,5]])
b=np.array([[7,8],[10,11]])

#Vertical Stacking
np.vstack([a,b])

#Horizontal Stacking
np.hstack([a,b])
# Out:
# array([[ 1,  2,  7,  8],
#        [ 4,  5, 10, 11]])
